# %% [markdown]
# <a href="https://colab.research.google.com/github/varunjanumpally31/KDAG-Tasks/blob/master/Level_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing all the required libraries

# %%
import numpy as np
import imageio as io
import matplotlib.pyplot as plt
import sklearn
from sklearn.cluster import KMeans

# %% [markdown]
# Visualization of Image

# %%
img = io.imread('/content/Image.jpeg')
plt.imshow(img/255.0)

# %% [markdown]
# Rescaling

# %%
data = np.reshape((img/255.0), (-1,3))

# %% [markdown]
# After 1 compressing into 1 cluster

# %%
kmeans =  KMeans(1).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_1_cluster.png',image_after_clustering)

# %% [markdown]
# After compressing into 2 clusters

# %%
kmeans =  KMeans(2).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_2_clusters.png',image_after_clustering)

# %% [markdown]
# After compressing into 3 clusters

# %%
kmeans =  KMeans(3).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_3_clusters.png',image_after_clustering)

# %% [markdown]
# After compressing into 4 clusters

# %%
kmeans =  KMeans(4).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_4_clusters.png',image_after_clustering)

# %% [markdown]
# After compressing into 5 clusters

# %%
kmeans =  KMeans(5).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_5_clusters.png',image_after_clustering)

# %% [markdown]
# After compressing into 6 clusters

# %%
kmeans =  KMeans(6).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_6_clusters.png',image_after_clustering)

# %% [markdown]
# After compressing into 8 clusters

# %%
kmeans =  KMeans(8).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_8_clusters.png',image_after_clustering)

# %% [markdown]
# After compressing into 10 clusters

# %%
kmeans =  KMeans(10).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_10_clusters.png',image_after_clustering)

# %% [markdown]
# After compressing into 15 clusters

# %%
kmeans =  KMeans(15).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_15_clusters.png',image_after_clustering)

# %% [markdown]
# After compressing into 25 clusters

# %%
kmeans =  KMeans(25).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_25_clusters.png',image_after_clustering)

# %% [markdown]
# After compressing into 45 clusters

# %%
kmeans =  KMeans(45).fit(data)
colors_after_clustering = kmeans.cluster_centers_[kmeans.predict(data)]
image_after_clustering = np.reshape(colors_after_clustering  , (img.shape))
plt.imshow(image_after_clustering)
plt.imsave('Image_after_compressing_into_45_clusters.png',image_after_clustering)
